# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\Intrusion detection system\IDS dataset\02-14-2018.csv")

# %%
# Assuming 'df' is the already imported DataFrame
# Randomly select 500 rows
df_sampled = df.sample(n=1000, random_state=42)  # random_state ensures reproducibility

# %%
df_sampled.head()
# Out:
#         Dst Port  Protocol            Timestamp  Flow Duration  Tot Fwd Pkts  \
# 781974        53        17  14/02/2018 08:44:26          36517             2
# 937737     49906         6  14/02/2018 09:31:42             51             1
# 907828        80         6  14/02/2018 04:13:41       53514166             2
# 784628       443         6  14/02/2018 11:05:34            272             3
# 662460        53        17  14/02/2018 03:23:23           1219             1
#
#         Tot Bwd Pkts  TotLen Fwd Pkts  TotLen Bwd Pkts  Fwd Pkt Len Max  \
# 781974             2               80              204               40
# 937737             1                0                0                0
# 907828             0                0                0                0
# 784628             0               77                0               46
# 662460             1               40              100               40
#
# ...

# %%
df_sampled.to_csv("sample_test.csv")
